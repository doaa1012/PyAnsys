# %%
import numpy as np
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("..")
from config import *
#from scripts.SNR import SNR
from scripts.plot_images import plot_images
from scripts.plot_line_defect import plot_line
from scripts.Amp_phase_func import *
from scripts.plot_rect import *
from scripts.simulation_func import *
from scripts.Saving_func import *
from scripts.SNR import *
from scripts.get_dft import *

# %%
# Larger_Density_Temp_time, Larger_Density_Loc_time
freq=[1.5, 2, 2.5, 3, 4,]
for f in freq:
   simulate_heat_transfer(f, DATA_CLEAN_Temp, DATA_CLEAN_Loc )
   break
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)
# Done_Temperature
# Done_Nodes
# 1.5
# (1702,)
# 729 Sound
# 1700 Defect_node
# Done

# %%
loaded_node_temp= pd.read_pickle(Dict_temp_1_5)
loaded_nodes_loc=pd.read_pickle(Nodes_loc_1_5)
loaded_node_temp.keys()
# Out:
# dict_keys([0.019999, 0.039998, 0.059997, 0.079996, 0.1, 0.11999, 0.13999, 0.15999, 0.17999, 0.19999, 0.21999, 0.23999, 0.25999, 0.27999, 0.29999, 0.31998, 0.33998, 0.35998, 0.37998, 0.39998, 0.41998, 0.43998, 0.45998, 0.47998, 0.49998, 0.51997, 0.53997, 0.55997, 0.57997, 0.59997, 0.61997, 0.63997, 0.65997, 0.67997, 0.69997, 0.71996, 0.73996, 0.75996, 0.77996, 0.79996, 0.81996, 0.83996, 0.85996, 0.87996, 0.89996, 0.91995, 0.93995, 0.95995, 0.97995, 0.99995, 1.0199, 1.0399, 1.0599, 1.0799, 1.0999, 1.1199, 1.1399, 1.1599, 1.1799, 1.1999, 1.2199, 1.2399, 1.2599, 1.2799, 1.2999, 1.3199, 1.3399, 1.3599, 1.3799, 1.3999, 1.4199, 1.4399, 1.4599, 1.4799, 1.4999, 1.5199, 1.5399, 1.5599, 1.5799, 1.5999, 1.6199, 1.6399, 1.6599, 1.6799, 1.6999, 1.7199, 1.7399, 1.7599, 1.7799, 1.7999, 1.8199, 1.8399, 1.8599, 1.8799, 1.8999, 1.9199, 1.9399, 1.9599, 1.9799, 1.9999, 2.0199, 2.0399, 2.0599, 2.0799, 2.0999, 2.1199, 2.1399, 2.1599, 2.1799, 2.1999, 2.2199, 2.2399, 2.2599, 2.2799, 2.2999, 2.3199, 2.3399, 2
# ...

# %%
len(loaded_nodes_loc)
# Out:
# 429

# %%
#loaded_node_temp((key) for key in loaded_node_temp.keys() if key > 39.564)
#New={key: loaded_node_temp[key] for key in loaded_node_temp.keys() if key > 90.895}

# %%
amplitude_DFT, phase_DFT=fourier_analysis(loaded_node_temp, 1.5)

# %%
grid_temperature, x_min, x_max, y_min, y_max, grid_x, grid_y= plot_images(amplitude_DFT, loaded_nodes_loc, label="Amplitude", plot_image=True)

# %%
grid_temperature, x_min, x_max, y_min, y_max, grid_x, grid_y= plot_images(phase_DFT, loaded_nodes_loc, label="Phase", plot_image=True)

# %%
new_node_temperature =[]
time = list(loaded_node_temp.keys())
# Using a loop
for key in loaded_node_temp:
    if len(loaded_node_temp[key]) >= 400:  
        new_node_temperature.append(loaded_node_temp[key][4])

plt.plot(time, new_node_temperature,  label='Original Data')

plt.xlabel('Time(s)')
plt.ylabel('Temp(t)')
plt.legend()
plt.show()

# %%
    freq=1.5
    Q = 1000
    omega = 2 * np.pi * freq  
    num_waves = 10
    room_temp = 25
    num_steps = 1000
    period = 1 / freq  
    t_end = num_waves * period  
    # Now, generate time_values and other related values as before
    time_values = np.linspace(0, t_end, num_steps, endpoint=False)
    cos_values = np.cos(omega * time_values)
    heat_flux = Q * (1 - cos_values)
    plt.plot(time_values,heat_flux)
    # Store time and heat_flux in the load_table
    load_table = np.column_stack((time_values, heat_flux))

# %%
#for k in loaded_node_temp.keys():
#plot_line(loaded_nodes_loc, loaded_node_temp[4.36], fixed_y=0.01, label="Temperature")

# %%
#plotting_all(Nodes_loc_1_5,Data_to_amp)

# %%
#df_CNR_Amp=get_df_CNR_Amp(Data_to_amp,loaded_nodes_loc, fixed_y=0.01, fixed_x=0.01, rect_size=4, margin=4)

# %%
#df_CNR_phase=get_df_CNR_phase(Data_to_amp,loaded_nodes_loc,fixed_y=0.01, fixed_x=0.01, rect_size=4, margin=4)

# %%
math.atan(1)
# Out:
# 0.7853981633974483

# %%
#depth_of_all(loaded_nodes_loc, Data_to_amp)

# %% [markdown]
# # For Large Density

# %%
node_temp_1_5= pd.read_pickle(Large_Dict_temp_1_5)
nodes_loc_1_5=pd.read_pickle(Larger_Density_loc_1_5)
node_temp_1_5.keys()
# Out:
# dict_keys([0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4, 0.42, 0.44, 0.46, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.68, 0.7, 0.72, 0.74, 0.76, 0.78, 0.8, 0.82, 0.84, 0.86, 0.88, 0.9, 0.92, 0.94, 0.96, 0.98, 1.0, 1.02, 1.04, 1.06, 1.08, 1.1, 1.12, 1.14, 1.16, 1.18, 1.2, 1.22, 1.24, 1.26, 1.28, 1.3, 1.32, 1.34, 1.36, 1.38, 1.4, 1.42, 1.44, 1.46, 1.48, 1.5, 1.52, 1.54, 1.56, 1.58, 1.6, 1.62, 1.64, 1.66, 1.68, 1.7, 1.72, 1.74, 1.76, 1.78, 1.8, 1.82, 1.84, 1.86, 1.88, 1.9, 1.92, 1.94, 1.96, 1.98, 2.0, 2.02, 2.04, 2.06, 2.08, 2.1, 2.12, 2.14, 2.16, 2.18, 2.2, 2.22, 2.24, 2.26, 2.28, 2.3, 2.32, 2.34, 2.36, 2.38, 2.4, 2.42, 2.44, 2.46, 2.48, 2.5, 2.52, 2.54, 2.56, 2.58, 2.6, 2.62, 2.64, 2.66, 2.68, 2.7, 2.72, 2.74, 2.76, 2.78, 2.8, 2.82, 2.84, 2.86, 2.88, 2.9, 2.92, 2.94, 2.96, 2.98, 3.0, 3.02, 3.04, 3.06, 3.08, 3.1, 3.12, 3.14, 3.16, 3.18, 3.2, 3.22, 3.24, 3.26, 3.28, 3.3, 3.32, 3.34, 3.36, 3.38, 3.4, 3
# ...

# %%
#save_amp_phase(freq, Larger_Density_Temp , Larger_Density_amp)

# %%
plot_line(nodes_loc_1_5, node_temp_1_5[58.94], fixed_y=0.01, label="Temperature")

# %%
#save_amp_phase(freq, Larger_Density_Temp_time, Larger_Density_time_amp)

# %%
#plotting_all(Larger_Density_loc_1_5,Larger_Density_amp )

# %%
df_CNR_Amp_Large_Density=get_df_CNR_Amp(Larger_Density_amp,nodes_loc_1_5, fixed_y=0.01, fixed_x=0.01, rect_size=4, margin=4)

# %%
df_CNR_phase_large_density=get_df_CNR_phase(Larger_Density_amp,nodes_loc_1_5,fixed_y=0.01, fixed_x=0.01, rect_size=4, margin=4)
# Out:
# For frequency: 1.5
# For frequency: 1.0
# For frequency: 2.5
# For frequency: 2.0
# For frequency: 3.5
# For frequency: 3.0
# For frequency: 4.0
# For frequency: 5.0
# For frequency: 6.0

# %%
df_CNR_Amp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Doaa Mohamed\Desktop\Doaa\PhD\pyansys\All_transient\Silicon_circle - Larger size\notebook\analysis_circle.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Doaa%20Mohamed/Desktop/Doaa/PhD/pyansys/All_transient/Silicon_circle%20-%20Larger%20size/notebook/analysis_circle.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df_CNR_Amp
#
# NameError: name 'df_CNR_Amp' is not defined

# %%
depth_of_all(nodes_loc_1_5,Larger_Density_amp)
# Out:
#    Frequency  phase_difference      Depth
# 0        1.5          0.063536   0.415253
# 1        1.0          0.035789   0.190986
# 2        2.5          0.002475   0.020885
# 3        2.0          0.001831   0.013815
# 4        3.5          0.032332   0.322786
# 5        3.0          0.017572   0.162421
# 6        4.0          0.002753   0.029385
# 7        5.0          2.656670  31.700882
# 8        6.0          0.117692   1.538402

# %%
plt.plot(freq, df_CNR_Amp["SNR"], marker='o', label='Coarse')
plt.plot(freq, df_CNR_Amp_Large_Density["SNR"], label='Fine')
plt.xlabel('Frequency')
plt.ylabel('CNR')
plt.title('Frequency vs CNR')
plt.grid(False)
plt.legend()  # Add a legend to distinguish between the lines

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(freq, df_CNR_Amp["SNR"], marker='o', label='Coarse')
#       2 plt.plot(freq, df_CNR_Amp_Large_Density["SNR"], label='Fine')
#       3 plt.xlabel('Frequency')
#
# File c:\Users\Doaa Mohamed\anaconda3\lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Doaa Mohamed\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
# ...

# %%
import pyvista

imported_mesh = pyvista.read('my_mesh.vtk')
scalars = imported_mesh.points[:, 2] 
plotter = imported_mesh.plot(
    color='gray',
    show_edges=True,
    screenshot="Doaa.png",
    #jupyter_backend="none"
)
# Out:
# c:\Users\Doaa Mohamed\anaconda3\lib\site-packages\pyvista\plotting\plotting.py:6138: UserWarning:
# Set `jupyter_backend` backend to `"none"` to take a screenshot within a notebook environment.
#   warnings.warn(
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)
